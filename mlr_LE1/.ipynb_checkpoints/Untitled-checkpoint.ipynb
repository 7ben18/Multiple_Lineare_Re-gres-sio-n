# %%
# Module importieren
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# DataFrame von GitHub einlesen
df = pd.read_csv("https://raw.githubusercontent.com/njtierney/melb-housing-data/master/data-raw/melbourne_housing_raw.csv")

# %%
# Ausgabe der Kopfzeile
df.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG     Date  Distance  \
# 0  Abbotsford      2    h        NaN     SS  Jellis   3/9/16       2.5
# 1  Abbotsford      2    h  1480000.0      S  Biggin  3/12/16       2.5
# 2  Abbotsford      2    h  1035000.0      S  Biggin   4/2/16       2.5
# 3  Abbotsford      3    u        NaN     VB  Rounds   4/2/16       2.5
# 4  Abbotsford      3    h  1465000.0     SP  Biggin   4/3/17       2.5
#
#    Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0    3067.0       2.0       1.0  1.0     126.0           NaN        NaN
# 1    3067.0       2.0       1.0  1.0     202.0           NaN        NaN
# 2    3067.0       2.0       1.0  0.0     156.0          79.0     1900.0
# 3    3067.0       3.0       2.0  1.0       0.0           NaN        NaN
# 4    3067.0       3.0       2.0  0.0     134.0         150.0     1900.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
# Anzahl einigartige Werte fuer jede Spalte ausgeben
df.nunique()
# Out:
# Suburb             351
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
# DataFrame Shapes
df.shape
# Out:
# (34857, 20)

# %%
# DataFrame verkleinern (filtern)
subcols = ['Suburb', 'Rooms', 'Type', 'SellerG', 'Regionname', 'Propertycount', 
 'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
 'BuildingArea', 'Price']
df = df[subcols]

# %%
df.head()
# Out:
#        Suburb  Rooms Type SellerG             Regionname  Propertycount  \
# 0  Abbotsford      2    h  Jellis  Northern Metropolitan         4019.0
# 1  Abbotsford      2    h  Biggin  Northern Metropolitan         4019.0
# 2  Abbotsford      2    h  Biggin  Northern Metropolitan         4019.0
# 3  Abbotsford      3    u  Rounds  Northern Metropolitan         4019.0
# 4  Abbotsford      3    h  Biggin  Northern Metropolitan         4019.0
#
#    Distance         CouncilArea  Bedroom2  Bathroom  Car  Landsize  \
# 0       2.5  Yarra City Council       2.0       1.0  1.0     126.0
# 1       2.5  Yarra City Council       2.0       1.0  1.0     202.0
# 2       2.5  Yarra City Council       2.0       1.0  0.0     156.0
# 3       2.5  Yarra City Council       3.0       2.0  1.0       0.0
# 4       2.5  Yarra City Council       3.0       2.0  0.0     134.0
#
#    BuildingArea      Price
# 0           NaN        NaN
# 1           NaN  1480000.0
# 2          79.0  1035000.0
# ...
